# %% [markdown]
# **정적 웹페이지**
# - 웹서버에 미리 저장된 HTML, 이미지 등을 말함
# - 시간이 지나도 변하지 않움
#
# **동적 웹페이지**
# - 웹서버가 데이터를 생성하거나 가공하여 전달해 주는 웹 페이지
# - 시간이 지남에 따라 또는 접속하는 사람이 누구인지에 따라 달라질 수 있음

# %% [markdown]
# **셀레니움**
# - 웹페이지 테스트 자동화를 할 수 있는 프레임워크
# - 셀레니움 사용하면 완전한 형태의 웹 페이지 소스를 볼 수 있기 때문에 동적 웹 페이지를 크롤링 할 때 유용

# %% [markdown]
# - 셀레니움을 사용하려면 사용중인 웹 브라우저의 드라이버 파일을 다운로드해야함
# - 크롬 드라이버 파일 다운로드 받기
# ```
# chrome://version/
# https://chromedriver.chromium.org/downloads 에서 chrome 버전과 운영체제에 맞는 드라이버 다운로드
# ```

# %% [markdown]
# - selenium 설치
# ```
# conda install selenium
# ```

# %% [markdown]
# - 참고 사이트
# ```
# https://www.selenium.dev/documentation/webdriver/
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import selenium

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome() # Driver가 있는 path를 넣어 줄 수 있음

# %%
driver.get("http://naver.com")

# %%
driver.back()

# %%
driver.forward()

# %%
driver.refresh()

# %% [markdown]
# - 더 자세한 내용은
# ```
# https://www.selenium.dev/documentation/webdriver/elements/
# ```

# %%
elem = driver.find_element_by_id("query")
#elem = driver.find_element_by_name("query")

# %%
elem = driver.find_element_by_id("query")
#elem = driver.find_element_by_name("query")

# %%
elem.send_keys("파이썬")

# %%
from selenium.webdriver.common.keys import Keys

# %%
elem.send_keys(Keys.ENTER)

# %%
elem = driver.find_element_by_tag_name("a")

# %%
elem.get_attribute("href")
# Out:
# 'https://search.naver.com/search.naver?where=nexearch&sm=top_sug.pre&fbm=1&acr=2&acq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&qdt=0&ie=utf8&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC#lnb'

# %%
elem = driver.find_elements_by_tag_name("a")
elem
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2fd691475ffddeca35d01c8886a12cbb", element="b2ce2833-eb87-4202-9e1b-fa42a98ae440")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2fd691475ffddeca35d01c8886a12cbb", element="6cb71f6b-aac1-4b69-81c8-1b2f99280566")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2fd691475ffddeca35d01c8886a12cbb", element="ee7fa478-e39b-4265-986f-9b84d082dbda")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2fd691475ffddeca35d01c8886a12cbb", element="d1058b2d-ee8c-4f6d-a4d0-f631ed7c83d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2fd691475ffddeca35d01c8886a12cbb", element="79bbb2ec-31e8-4d70-945c-8d7e5b07739f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2fd691475ffddeca35d01c8886a12cbb", element="e3134250-8bd1-4561-b10c-c6eedece65ae")>,
# ...

# %%
for e in elem:
    print(e.get_attribute("href"))
# Out:
# https://search.naver.com/search.naver?where=nexearch&sm=top_sug.pre&fbm=1&acr=2&acq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&qdt=0&ie=utf8&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC#lnb
# https://search.naver.com/search.naver?where=nexearch&sm=top_sug.pre&fbm=1&acr=2&acq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&qdt=0&ie=utf8&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC#content
# https://www.naver.com/
# https://search.naver.com/search.naver?where=nexearch&sm=top_sug.pre&fbm=1&acr=2&acq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&qdt=0&ie=utf8&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC#
# https://search.naver.com/search.naver?where=nexearch&sm=top_sug.pre&fbm=1&acr=2&acq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&qdt=0&ie=utf8&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC#
# https://search.naver.com/search.naver?where=nexearch&sm=top_sug.pre&fbm=1&acr=2&acq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&qdt=0&ie=utf8&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC#
# ...

# %% [markdown]
# **다음 사이트에서 위와 유사한 동작 해보기**

# %%
driver.get("http://daum.net")

# %%
#elem = driver.find_element_by_id("q")
elem = driver.find_element_by_name("q")

# %%
elem.send_keys("파이썬")

# %%
elem = driver.find_element_by_xpath('//*[@id="daumSearch"]/fieldset/div/div/button[3]')

# %%
elem.click()

# %%
elem = driver.find_elements_by_tag_name("a")
for e in elem:
    print(e.get_attribute("href"))
# Out:
# https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%ED%8C%8C%EC%9D%B4%EC%8D%AC#daumBody
# https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%ED%8C%8C%EC%9D%B4%EC%8D%AC#daumGnb
# https://www.daum.net/?nil_profile=daum&nil_src=search
# http://cs.daum.net/faq/15/14957.html#28978
# https://logins.daum.net/accounts/loginform.do?url=https%3A%2F%2Fsearch.daum.net%2Fsearch%3Fw%3Dtot%26DA%3DYZR%26t__nil_searchbox%3Dbtn%26sug%3D%26sugo%3D%26sq%3D%26o%3D%26q%3D%25ED%258C%258C%25EC%259D%25B4%25EC%258D%25AC
# https://mail.daum.net/?nil_profile=mini&nil_src=mail
# https://accounts.daum.net/mail/create
# http://www.daum.net/doc/sitemap/?nil_profile=mini&nil_src=sitemap
# https://cafe.daum.net/?nil_profile=mini&nil_src=cafe
# https://news.daum.net/?nil_profile=mini&nil_src=news
# https://map.kakao.com/?nil_profile=mini&nil_src=map
# https://shoppinghow.kakao.com/top?nil_profile=mini&nil_src=shophow
# ...

# %%
driver.close() # Browser 종료

# %%
driver.quit() # Browser 종료 & Chrome Driver 종료

# %% [markdown]
# ### Workshop

# %%
from selenium import webdriver
import time
import urllib.request

# %% [markdown]
# **이미지 검색하기**

# %%
browser = webdriver.Chrome()
browser.maximize_window()

url = "https://www.google.co.kr/imghp?hl=ko&tab=ri&ogbl"
browser.get(url)

# %%
elem = browser.find_element_by_name("q")
keyword = "딸기"
elem.send_keys(keyword)
elem.submit()

# %% [markdown]
# **이미지 클릭한 후 원본 다운로드 받기**

# %% [markdown]
# **CSS 선택자**
# ```
# https://www.w3schools.com/cssref/css_selectors.asp
# ```

# %%
count = 1
images = browser.find_elements_by_css_selector(".rg_i.Q4LuWd")
#images = browser.find_elements_by_css_selector("img.rg_i.Q4LuWd")
for image in images:
    image.click()
    time.sleep(2)
    
    imgUrl = browser.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img').get_attribute("src")
    
#     tmp = browser.find_element_by_css_selector(".n3VNCb.KAlRDb")
#     imgUrl = tmp.get_attribute("src")
    print(imgUrl)
    
    urllib.request.urlretrieve(imgUrl, keyword + str(count) + ".jpg")
    count = count + 1
    if count > 10:
        break;
browser.quit()
# Out:
# https://m.nongmin.com/upload/bbs/202202/20220213000003506/20220213000003506.jpg
# https://biz.chosun.com/resizer/euLrheFZgSB8pUXW-H9fcGoHiwE=/1280x0/smart/cloudfront-ap-northeast-1.images.arcpublishing.com/chosunbiz/7QXLKA2FIZGVPBBLSBLZQNWJGQ.jpg
# https://images.mypetlife.co.kr/content/uploads/2019/07/09153528/berry-close-up-delicious-934066.jpg
# https://img.hankyung.com/photo/202201/01.28483975.1.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Strawberry_BNC.jpg/1200px-Strawberry_BNC.jpg
# https://pds.joins.com/news/component/htmlphoto_mmdata/201501/08/htm_20150108173856c010c011.jpg
# https://img.kr.news.samsung.com/kr/wp-content/uploads/2017/02/%ED%91%B8%EB%93%9C%ED%8F%AC%EC%BB%A4%EC%8A%A42%ED%8E%B807.jpg
# http://cdn.agrinet.co.kr/news/photo/202202/307200_42173_1727.jpg
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %% [markdown]
# **user agent 정보 추가하기**

# %%
options = webdriver.ChromeOptions()
#options.headless = True
options.add_argument("window-size=1920x1080")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.115 Safari/537.36")

browser = webdriver.Chrome(options=options)
browser.maximize_window()

url = "https://www.google.co.kr/imghp?hl=ko&tab=ri&ogbl"
browser.get(url)

elem = browser.find_element_by_name("q")
keyword = "딸기"
elem.send_keys(keyword)
elem.submit()

count = 1
images = browser.find_elements_by_css_selector(".rg_i.Q4LuWd")
for image in images:
    image.click()
    time.sleep(2)
    #imgUrl = browser.find_element_by_xpath("//*[@id='Sva75c']/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div[1]/a/img").get_attribute("src")
    imgUrl = browser.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img').get_attribute("src")
    
#     tmp = browser.find_element_by_css_selector(".n3VNCb.KAlRDb")
#     imgUrl = tmp.get_attribute("src")
    print(imgUrl)
    
    urllib.request.urlretrieve(imgUrl, keyword + str(count) + ".jpg")
    count = count + 1
    if count > 10:
        break;
browser.quit()

# %% [markdown]
# **검색 화면에서 자동 스크롤하기**

# %%
options = webdriver.ChromeOptions()
#options.headless = True
options.add_argument("window-size=1920x1080")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.115 Safari/537.36")
browser = webdriver.Chrome(options=options)
browser.maximize_window()

url = "https://www.google.co.kr/imghp?hl=ko&tab=ri&ogbl"
browser.get(url)

elem = browser.find_element_by_name("q")
keyword = "딸기"
elem.send_keys(keyword)
elem.submit()

# %%
# 지정한 위치로 스크롤 내리기
# 모니터(해상도) 높이인 1080 위치로 스크롤 내리기
#browser.execute_script("window.scrollTo(0, 1080)") # 1920 x 1080
#browser.execute_script("window.scrollTo(0, 2080)")

# %%
# 화면 가장 아래로 스크롤 내리기
# browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

# %%
import time
interval = 2 # 2초에 한번씩 스크롤 내림

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")
print("prev", prev_height)
# 반복 수행
while True:
    # 스크롤을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    # 페이지 로딩 대기
    time.sleep(interval)

    # 현재 문서 높이를 가져와서 저장
    curr_height = browser.execute_script("return document.body.scrollHeight")
    print("curr", curr_height)
    if curr_height == prev_height:
        break

    prev_height = curr_height
    print("prev", prev_height)

print("스크롤 완료")
# Out:
# prev 2583
# curr 4773
# prev 4773
# curr 8903
# prev 8903
# curr 12791
# prev 12791
# curr 16921
# prev 16921
# curr 17002
# prev 17002
# curr 17002
# 스크롤 완료

# %%
count = 1
images = browser.find_elements_by_css_selector(".rg_i.Q4LuWd")
#images = browser.find_elements_by_css_selector("img.rg_i.Q4LuWd")
for image in images:
    image.click()
    time.sleep(2)

    imgUrl = browser.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img').get_attribute("src")
    
    #tmp = browser.find_element_by_css_selector(".n3VNCb.KAlRDb")
    #tmp = browser.find_element_by_css_selector(".n3VNCb")
    #imgUrl = tmp.get_attribute("src")
    #print(imgUrl)
    
    urllib.request.urlretrieve(imgUrl, keyword + str(count) + ".jpg")
    count = count + 1
    if count > 20:
        break;
browser.quit()
# Out:
# https://m.nongmin.com/upload/bbs/202202/20220213000003506/20220213000003506.jpg
# https://biz.chosun.com/resizer/euLrheFZgSB8pUXW-H9fcGoHiwE=/1280x0/smart/cloudfront-ap-northeast-1.images.arcpublishing.com/chosunbiz/7QXLKA2FIZGVPBBLSBLZQNWJGQ.jpg
# https://images.mypetlife.co.kr/content/uploads/2019/07/09153528/berry-close-up-delicious-934066.jpg
# https://img.hankyung.com/photo/202201/01.28483975.1.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Strawberry_BNC.jpg/1200px-Strawberry_BNC.jpg
# https://pds.joins.com/news/component/htmlphoto_mmdata/201501/08/htm_20150108173856c010c011.jpg
# https://img.kr.news.samsung.com/kr/wp-content/uploads/2017/02/%ED%91%B8%EB%93%9C%ED%8F%AC%EC%BB%A4%EC%8A%A42%ED%8E%B807.jpg
# http://cdn.agrinet.co.kr/news/photo/202202/307200_42173_1727.jpg
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# http://img.etoday.co.kr/pto_db/2021/12/20211217154557_1698637_700_385.jpg
# ...

# %% [markdown]
# **네이버 로그인**

# %%
# 0. 웹드라이버 구동
browser = webdriver.Chrome()

# 1. 네이버 사이트 이동
browser.get("http://naver.com")

# 2. 로그인 버튼
elem = browser.find_element_by_class_name("link_login")
elem.click()

# 3. id, pw 입력
elem = browser.find_element_by_id("id")
elem.send_keys("my_id")
time.sleep(3)
elem = browser.find_element_by_id("pw")
elem.send_keys("my_pw")

# 4. 로그인 버튼 클릭
elem = browser.find_element_by_id("log.login")
elem.click()

browser.quit()
